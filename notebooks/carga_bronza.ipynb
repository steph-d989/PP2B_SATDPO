# %%
import pandas as pd
import os 
import sys
import tomllib

sys.path.append(os.path.abspath("../.secrets"))
from db_config import get_connection

print("Se conectó a la bbdd correctamente...")
# Out:
# Running cells with 'venv_bda_idl2 (3.12.4) (Python 3.12.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"d:/INSTITUTO CONTINENTAL/4. CICLO - 4/BIG DATA APLICADA/IDL2_BDA_CARDENAS_DAMIANI/PP2B_SATDPO_Sistema_Alerta_Temprana_Desempe-o_Personal_Operativo/venv_bda_idl2/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
with open("../.secrets/secrets.toml", "rb") as f:
    config = tomllib.load(f)

ruta_archivos = config["paths"]["bronze_path"]

print("Ruta configurada: ", ruta_archivos)
# Out:
# Running cells with 'venv_bda_idl2 (3.12.4) (Python 3.12.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"d:/INSTITUTO CONTINENTAL/4. CICLO - 4/BIG DATA APLICADA/IDL2_BDA_CARDENAS_DAMIANI/PP2B_SATDPO_Sistema_Alerta_Temprana_Desempe-o_Personal_Operativo/venv_bda_idl2/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
